# %%
import pandas as pd

# %%
data= pd.read_csv("/home/yashwant/Documents/summer_work/cosmic_skill_course/Housing_Data.csv")

# %%
data
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 0     42000.0     5850         3        1        2      yes      no      yes
# 1     38500.0     4000         2        1        1      yes      no       no
# 2     49500.0     3060         3        1        1      yes      no       no
# 3     60500.0     6650         3        1        2      yes     yes       no
# 4     61000.0     6360         2        1        1      yes      no       no
# 5     66000.0     4160         3        1        1      yes     yes      yes
# 6     66000.0     3880         3        2        2      yes      no      yes
# 7     69000.0     4160         3        1        3      yes      no       no
# 8     83800.0     4800         3        1        1      yes     yes      yes
# 9     88500.0     5500         3        2        4      yes     yes       no
# 10    90000.0     7200         3        2        1      yes      no      yes
# 11    30500.0     3000         2        1        1       no      no       no
# 12    27000.0     1700         3        1        2      yes      no       no
# 13    36000.0     2880         3        1        1       no      no       no
# 14    37000.0     3600         2        1        1      yes      no       no
# 15    37900.0     3185         2        1        1      yes      no       no
# 16    40500.0     3300         3        1        2       no      no       no
# 17    40750.0     5200         4        1        3      yes      no       no
# 18    45000.0     3450         1        1        1      yes      no       no
# 19    45000.0     3986         2        2        1       no     yes      yes
# 20    48500.0     4785         3        1        2      yes     yes      yes
# 21    65900.0     4510         4        2        2      yes      no      yes
# 22    37900.0     4000         3        1        2      yes      no       no
# 23    38000.0     3934         2        1        1      yes      no       no
# 24    42000.0     4960         2        1        1      yes      no       no
# 25    42300.0     3000         2        1        2      yes      no       no
# 26    43500.0     3800         2        1        1      yes      no       no
# 27    44000.0     4960         2        1        1      yes      no      yes
# 28    44500.0     3000         3        1        1       no      no       no
# 29    44900.0     4500         3        1        2      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 516   95000.0     6000         3        2        3      yes     yes       no
# 517   96500.0     6000         4        2        4      yes      no       no
# 518  101000.0     6240         4        2        2      yes      no       no
# 519  102000.0     6000         3        2        2      yes     yes       no
# 520  103000.0     7680         4        2        4      yes     yes       no
# 521  105000.0     6000         4        2        4      yes     yes       no
# 522  108000.0     6000         4        2        4      yes      no       no
# 523  110000.0     6000         4        2        4      yes      no       no
# 524  113000.0     6000         4        2        4      yes      no       no
# 525  120000.0     7475         3        2        4      yes      no       no
# 526  105000.0     5150         3        2        4      yes      no       no
# 527  106000.0     6325         3        1        4      yes      no       no
# 528  107500.0     6000         3        2        4      yes      no       no
# 529  108000.0     6000         3        2        3      yes      no       no
# 530  113750.0     6000         3        1        4      yes     yes       no
# 531  120000.0     7000         3        1        4      yes      no       no
# 532   70000.0    12900         3        1        1      yes      no       no
# 533   71000.0     7686         3        1        1      yes     yes      yes
# 534   82000.0     5000         3        1        3      yes      no       no
# 535   82000.0     5800         3        2        4      yes      no       no
# 536   82500.0     6000         3        2        4      yes      no       no
# 537   83000.0     4800         3        1        3      yes      no       no
# 538   84000.0     6500         3        2        3      yes      no       no
# 539   85000.0     7320         4        2        2      yes      no       no
# 540   85000.0     6525         3        2        4      yes      no       no
# 541   91500.0     4800         3        2        4      yes     yes       no
# 542   94000.0     6000         3        2        4      yes      no       no
# 543  103000.0     6000         3        2        4      yes     yes       no
# 544  105000.0     6000         3        2        2      yes     yes       no
# 545  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# 0      no    no         1       no
# 1      no    no         0       no
# 2      no    no         0       no
# 3      no    no         0       no
# 4      no    no         0       no
# 5      no   yes         0       no
# 6      no    no         2       no
# 7      no    no         0       no
# 8      no    no         0       no
# 9      no   yes         1       no
# 10     no   yes         3       no
# 11     no    no         0       no
# 12     no    no         0       no
# 13     no    no         0       no
# 14     no    no         0       no
# 15     no   yes         0       no
# 16     no    no         1       no
# 17     no    no         0       no
# 18     no    no         0       no
# 19     no    no         1       no
# 20     no   yes         1       no
# 21     no    no         0       no
# 22     no   yes         0       no
# 23     no    no         0       no
# 24     no    no         0       no
# 25     no    no         0       no
# 26     no    no         0       no
# 27     no   yes         0       no
# 28     no   yes         0       no
# 29     no   yes         0       no
# ..    ...   ...       ...      ...
# 516    no   yes         0       no
# 517    no   yes         0       no
# 518    no   yes         1       no
# 519    no    no         1       no
# 520    no   yes         1       no
# 521    no   yes         1       no
# 522    no   yes         1       no
# 523    no    no         2       no
# 524    no   yes         1       no
# 525    no   yes         2       no
# 526    no   yes         2       no
# 527    no   yes         1       no
# 528    no   yes         1       no
# 529    no   yes         0       no
# 530    no   yes         2       no
# 531    no   yes         2       no
# 532    no    no         2       no
# 533   yes    no         0       no
# 534    no   yes         0       no
# 535    no   yes         0       no
# 536    no   yes         0       no
# 537    no   yes         0       no
# 538    no   yes         0       no
# 539    no    no         0       no
# 540    no    no         1       no
# 541    no   yes         0       no
# 542    no   yes         0       no
# 543    no   yes         1       no
# 544    no   yes         1       no
# 545    no   yes         1       no
#
# [546 rows x 12 columns]

# %%
import numpy as np

# %%
x = np.array(data[('lotsize')])

# %%
y= np.array(data[('price')])

# %%
x.shape
# Out:
# (546,)

# %%
y.shape
# Out:
# (546,)

# %%
x= x.reshape(len(x),1)

# %%
y=y.reshape(len(y),1)

# %%
x_train = x[:-250]
y_train = y[:-250]
x_test = x[-250:]
y_test = y[-250:]
# %matplotlib inline
import matplotlib.pyplot as plt
plt.ylabel('y')
plt.xlabel("x")
plt.title('plot')
plt.scatter(x_train,y_train,color='green')

# %%
plt.scatter?

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()

# %%
regr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,regr.predict(x_test),color='green',linewidth=3)
plt.title('Test data')
plt.xlabel('lotsize')
plt.ylabel('Price')
plt.show()

# %%
regr.predict(8000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-96e529dc4889> in <module>
# ----> 1 regr.predict([8000])
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/linear_model/base.py in _decision_function(self, X)
#     194         check_is_fitted(self, "coef_")
#     195
# --> 196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     197         return safe_sparse_dot(X, self.coef_.T,
#     198                                dense_output=True) + self.intercept_
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     550                     "Reshape your data either using array.reshape(-1, 1) if "
#     551                     "your data has a single feature or array.reshape(1, -1) "
# --> 552                     "if it contains a single sample.".format(array))
#     553
#     554         # in the future np.flexible dtypes will be handled like object dtypes
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[8000].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
